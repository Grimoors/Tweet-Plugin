# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install -q xlrd
# !pip install tensorflowjs
import tensorflowjs as tfjs
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# WARNING:root:TensorFlow Decision Forests 1.2.0 is compatible with the following TensorFlow Versions: ['2.11.0']. However, TensorFlow 2.11.1 was detected. This can cause issues with the TF API and symbols in the custom C++ ops. See the TF and TF-DF compatibility table at https://github.com/tensorflow/decision-forests/blob/main/documentation/known_issues.md#compatibility-table.

# %%
c1 = pd.read_excel("/content/Topic_abortion (1).xlsx")
c1.head()
# Out:
#    no             authorid  user_username  following  followers  totaltweets  \
# 0   0             23320357       rwindrem        260       3262        31025
# 1   1             37494078          xotmc       1253       1659        60923
# 2   2  1549385291558840064  abortourcourt        452         93         1899
# 3   3  1461120561292009984    BarryGore15        143         34        35629
# 4   4             46430064      sallyray5       3770       1349       274902
#
#           user_location  likeCount  retweetcount  view_count  ...  \
# 0  The swamps of Jersey          0          7788           0  ...
# 1           Atlanta, GA          0          7788           0  ...
# 2          Portland, OR          0             9           0  ...
# 3                   NaN          0          7788           0  ...
# 4            Texas, USA          0          7788           0  ...
#
#       user_displayname                                        description  \
# ...

# %%
nc1 = pd.read_excel("/content/Topic_seatbelts.xlsx")
nc1.head()

# %%
# remove rows with 0 likes and 0 views
frames = [c1, nc1]
df = pd.concat(frames)
df = df[(df['likeCount'] != 0) & (df['view_count'] != 0)]
df.head()

# %%
df1 = df[['translatedText', 'likeCount']]

# %%
X = df1['translatedText']
y = df1['likeCount']

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# assuming X is a pandas DataFrame with a column of text documents and y is a list of target values
X.fillna("", inplace=True)

# convert the text data to a list
X = X.tolist()

# vectorize the text data using CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X)

# train the linear regression model
reg_model = LinearRegression()
reg_model.fit(X, y)

import pickle

with open('model.pkl', 'wb') as f:
    pickle.dump(model, f)

with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

tfjs.converters.save_keras_model(reg_model, 'model_like_prediction')

# make predictions and calculate RMSE
y_pred = reg_model.predict(X)
rmse = mean_squared_error(y, y_pred, squared=False)

print("Root Mean Squared Error:", rmse)

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression

# create a new text input for prediction
new_text = ["you are too lazy to do anything"]

# vectorize the new text input using the same CountVectorizer
new_text_vec = vectorizer.transform(new_text)

# use the trained model to predict the number of likes for the new text input
likes_pred = reg_model.predict(new_text_vec)[0]

print("Predicted number of likes:", round(likes_pred))

# %% [markdown]
# Sentiment prediction

# %%
df2 = df[['translatedText', 'vaderSentiment']]
X = df2['translatedText']
y = df2['vaderSentiment']

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# assuming X is a pandas DataFrame with a column of text documents and y is a list of target values
X.fillna("", inplace=True)

# convert the text data to a list
X = X.tolist()

# vectorize the text data using CountVectorizer
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(X)

# train the linear regression model
reg_model = LinearRegression()
reg_model.fit(X, y)

tfjs.converters.save_keras_model(reg_model, 'model_sentiment_prediction')

# make predictions and calculate RMSE
y_pred = reg_model.predict(X)
rmse = mean_squared_error(y, y_pred, squared=False)

print("Root Mean Squared Error:", rmse)

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LinearRegression

# create a new text input for prediction
new_text = ["Veery bad. Pathetic"]

# vectorize the new text input using the same CountVectorizer
new_text_vec = vectorizer.transform(new_text)

# use the trained model to predict the number of likes for the new text input
likes_pred = reg_model.predict(new_text_vec)[0]

print("Predicted sentiment:", likes_pred)
